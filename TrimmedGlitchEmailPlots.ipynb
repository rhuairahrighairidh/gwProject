# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
pd.options.display.mpl_style = 'default'

# %%
noiseErrors={0.0: {'average': 0.23153027366553233, 'stdDev': 8.3266726846886741e-17},
 0.05: {'average': 0.16687443184845052, 'stdDev': 0.020363370566747641},
 0.1: {'average': 0.20216047273833182, 'stdDev': 0.024720274325523914},
 0.15: {'average': 0.24905030762469962, 'stdDev': 0.037778296504855875},
 0.2: {'average': 0.27206854773979122, 'stdDev': 0.049102401646457329},
 0.25: {'average': 0.31489391041582265, 'stdDev': 0.055724143176150612},
 0.3: {'average': 0.37416413062903175, 'stdDev': 0.068645465261479341},
 0.35: {'average': 0.42696026584315661, 'stdDev': 0.074953040696245352},
 0.4: {'average': 0.4738828268661483, 'stdDev': 0.095076197519065875},
 0.45: {'average': 0.49890955929799496, 'stdDev': 0.087855395416372745},
 0.5: {'average': 0.55198238737117489, 'stdDev': 0.098472927957103787}}

# %%
signalErrors={0.0: {'average': 0.0011270271326938137, 'stdDev': 2.1684043449710089e-19},
 0.05: {'average': 0.15944434741573299, 'stdDev': 0.037500908822253508},
 0.1: {'average': 0.20739466408948334, 'stdDev': 0.034126303253348714},
 0.15: {'average': 0.25256012678609474, 'stdDev': 0.039048123513288034},
 0.2: {'average': 0.29527523359718361, 'stdDev': 0.043929359253042623},
 0.25: {'average': 0.33374257857164358, 'stdDev': 0.04886041960838803},
 0.3: {'average': 0.38243014500423994, 'stdDev': 0.065275793959378117},
 0.35: {'average': 0.43447604667937822, 'stdDev': 0.096114208815013757},
 0.4: {'average': 0.4502318764684532, 'stdDev': 0.086259120937188294},
 0.45: {'average': 0.51623612439132815, 'stdDev': 0.099755916080487159},
 0.5: {'average': 0.56573184423069245, 'stdDev': 0.11292432599138205}}

# %%
(fig,ax)=plt.subplots(1,1)

sx = sorted(signalErrors.keys())
sy = [signalErrors[n]['average'] for n in sx]
ser = [signalErrors[n]['stdDev'] for n in sx]
ax.errorbar(sx,sy,marker='x',linestyle='-',yerr=ser,label='trimmedGltich1')

nx = sorted(noiseErrors.keys())
ny = [noiseErrors[n]['average'] for n in nx]
ner = [noiseErrors[n]['stdDev'] for n in nx]
ax.errorbar(nx,ny,marker='x',linestyle='-',yerr=ner,label='pure noise')

ax.set_xlim(left=-0.01,right=0.51)
ax.set_ylim(bottom=-0.02,top = 1.02)
ax.set_ylabel('Average Error')
ax.set_xlabel('Standard Deviation of Noise Added In Testing')
ax.legend()
fig.set_size_inches([10,7])

# %%
noiseAnomalies={0.0: {'average': 0.99995238095238093, 'stdDev': 0.00047380354147935231},
 0.05: {'average': 0.85999999999999999, 'stdDev': 0.06520289283122406},
 0.1: {'average': 0.78270238095238098, 'stdDev': 0.070388953206878213},
 0.15: {'average': 0.79057142857142837, 'stdDev': 0.064943216082919267},
 0.2: {'average': 0.82092857142857156, 'stdDev': 0.059907141863541638},
 0.25: {'average': 0.84469047619047632, 'stdDev': 0.054633757931053344},
 0.3: {'average': 0.86483184057321993, 'stdDev': 0.054765714301476927},
 0.35: {'average': 0.87184585484086385, 'stdDev': 0.057085593050870756},
 0.4: {'average': 0.8809122364074724, 'stdDev': 0.05037502326487156},
 0.45: {'average': 0.89727951537774575, 'stdDev': 0.05764591404939437},
 0.5: {'average': 0.89331018036712206, 'stdDev': 0.048858537241867006}}

# %%
signalAnomalies={0.0: {'average': 0.028761904761904766, 'stdDev': 0.0018952141659173711},
 0.05: {'average': 0.49601190476190482, 'stdDev': 0.086309339080262087},
 0.1: {'average': 0.70654165279165293, 'stdDev': 0.082972660799193076},
 0.15: {'average': 0.79645868882075777, 'stdDev': 0.071690231256020351},
 0.2: {'average': 0.82524233429405858, 'stdDev': 0.059391450867669185},
 0.25: {'average': 0.85477439111604281, 'stdDev': 0.058036636749310005},
 0.3: {'average': 0.85792106942764845, 'stdDev': 0.057264301081948264},
 0.35: {'average': 0.86906813646627612, 'stdDev': 0.062383518780703161},
 0.4: {'average': 0.88570188437293706, 'stdDev': 0.047316577769524984},
 0.45: {'average': 0.88322234473028505, 'stdDev': 0.053085534171044779},
 0.5: {'average': 0.88635211277429971, 'stdDev': 0.056259631941503359}}

# %%
(fig,ax)=plt.subplots(1,1)

sx = sorted(signalAnomalies.keys())
sy = [signalAnomalies[n]['average'] for n in sx]
ser = [signalAnomalies[n]['stdDev'] for n in sx]
ax.errorbar(sx,sy,marker='x',linestyle='-',yerr=ser,label='trimmedGltich1')

nx = sorted(noiseAnomalies.keys())
ny = [noiseAnomalies[n]['average'] for n in nx]
ner = [noiseAnomalies[n]['stdDev'] for n in nx]
ax.errorbar(nx,ny,marker='x',linestyle='-',yerr=ner,label='pure noise')

ax.set_xlim(left=-0.01,right=0.51)
ax.set_ylim(bottom=-0.02,top = 1.02)
ax.set_ylabel('Average Anomaly')
ax.set_xlabel('Standard Deviation of Noise Added In Testing')
ax.legend(loc=0)
fig.set_size_inches([10,7])
